# %%
import pandas as pd
import numpy as np


from matplotlib import pyplot as plt
from matplotlib import animation

#data = pd.read_csv('DataStream',header=None)


ED = pd.read_csv("ElectricDevices_TEST",header=None)
list_1=[]
list_2=[]
list_3=[]
list_4=[]
list_5=[]
list_6=[]
g = ED.T

#print(g)
print("总列数为：",len(ED))

for i in range (len(ED)):
    if g[i][0]==6:
        #print(i)
        list_6.append(i)
print("list 6:",list_6)
print("\n\n\n")

for i in range (len(ED)):
    if g[i][0]==5:
        #print(i)
        list_5.append(i)
print("list 5:",list_5)
print("\n\n\n")

for i in range (len(ED)):
    if g[i][0]==4:
        #print(i)
        list_4.append(i)
print("list 4:",list_4)
print("\n\n\n")

for i in range (len(ED)):
    if g[i][0]==3:
        #print(i)
        list_3.append(i)
print("list 3:",list_3)
print("\n\n\n")

for i in range (len(ED)):
    if g[i][0]==2:
        #print(i)
        list_2.append(i)
print("list 2:",list_2)
print("\n\n\n")

for i in range (len(ED)):
    if g[i][0]==1:
        #print(i)
        list_1.append(i)
print("list 1:",list_1)
print("\n\n\n")

#
# ED1 = pd.read_csv("ElectricDevices_TEST - 副本")
# feature = np.array(ED.T)
# #print(feature)
#
# Out:
# 总列数为： 7711
# ...

# %%
import pandas as pd
import numpy as np


from matplotlib import pyplot as plt
from matplotlib import animation


ED = pd.read_csv("ElectricDevices_TEST",header=None)
#g = ED.T
#print(g[1])
#

plt.figure(figsize=(9,7))
# plt.subplot(n_rows, n_cols, plot_num)

#list 6: [0, 1,
plt.subplot(4, 4, 5)
plt.plot(g[0])

plt.subplot(4, 4, 6)
plt.plot(g[1])

#list 5: [122, 123
plt.subplot(4, 4, 7)
plt.plot(g[122],color="red")

plt.subplot(4, 4, 8)
plt.plot(g[123],color="red")
#list 4: [135, 136
plt.subplot(4, 4, 9)
plt.plot(g[135],color="black")

plt.subplot(4, 4, 10)
plt.plot(g[136],color="black")
#list 3: [739, 740,
plt.subplot(4, 4, 11)
plt.plot(g[135],color="#808080")

plt.subplot(4, 4, 12)
plt.plot(g[136],color="#808080")

#list 2: [1062, 1063,
plt.subplot(4, 4, 13)
plt.plot(g[1062],color="#008000")

plt.subplot(4, 4, 14)
plt.plot(g[1063],color="#008000")
#list 1: [338, 339,
plt.subplot(4, 4, 15)
plt.plot(g[338],color="#FFFF00")

plt.subplot(4, 4, 16)
plt.plot(g[339],color="#FFFF00")


#plt.legend(["6", "5","4", "3","2", "1"], loc=6)
####
plt.subplot(4, 1, 1)
plt.plot(g)

plt.show()

# %%
import math


math.sqrt(9)
# Out:
# 3.0

# %%
abs(-1)
# Out:
# 1

# %%
#print(g[0])
print(g[0].drop([0]))
# Out:
# 1    -0.19621
# 2    -0.19621
# 3    -0.19621
# 4    -0.19621
# 5    -0.19621
# 6    -0.19621
# 7    -0.19621
# 8    -0.19621
# 9    -0.19621
# 10   -0.19621
# 11   -0.19621
# 12   -0.19621
# 13   -0.19621
# 14   -0.19621
# 15    1.46990
# 16    9.13380
# 17    1.64630
# 18    1.15620
# 19    0.74463
# 20    0.47021
# 21    0.52902
# 22    0.50942
# 23    0.64662
# 24    0.56822
# 25   -0.19621
# 26   -0.19621
# 27   -0.19621
# 28   -0.19621
# 29   -0.19621
# 30   -0.19621
#        ...
# 67   -0.19621
# 68   -0.19621
# 69   -0.19621
# 70   -0.19621
# 71   -0.19621
# 72   -0.19621
# 73   -0.19621
# 74   -0.19621
# 75   -0.19621
# 76   -0.19621
# 77   -0.19621
# 78   -0.19621
# 79   -0.19621
# 80   -0.19621
# 81   -0.19621
# 82   -0.19621
# 83   -0.19621
# 84   -0.19621
# 85   -0.19621
# 86   -0.19621
# 87   -0.19621
# 88   -0.19621
# 89   -0.19621
# 90   -0.19621
# 91   -0.19621
# 92   -0.19621
# 93   -0.19621
# 94   -0.19621
# 95   -0.19621
# 96   -0.19621
# ...
